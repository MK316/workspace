# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/workspace/blob/main/ASR01/ASR03_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sentence recognition
#
# Note: change 'runtime' type to 'gpu' before you start.

# %%
from IPython.display import Audio
import pandas as pd

# %% [markdown]
# Audio file from Github
# https://github.com/MK316/workspace/tree/main/ASR01/SE

# %%
# checking
url = "https://github.com/MK316/workspace/raw/main/ASR01/SE/SE01.wav"
Audio(url)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Text file from Github https://raw.githubusercontent.com/MK316/workspace/main/ASR01/data/rainbow_sentences.csv

# %%
# Sentence texts to bring
url = "https://raw.githubusercontent.com/MK316/workspace/main/ASR01/data/rainbow_sentences.csv"
data = pd.read_csv(url)
data.head()
# Out:
#    SN                                           Sentence
# 0  S1  When the sunlight strikes raindrops in the air...
# 1  S2  The rainbow is a division of white light into ...
# 2  S3  These take the shape of a long round arch, wit...
# 3  S4  There is, according to legend, a boiling pot o...
# 4  S5             People look, but no one ever finds it.

# %% [markdown]
# ## ASR to install
#
# model (base.en)

# %%
#@markdown Install SR tool
# %%capture
# !pip install git+https://github.com/openai/whisper.git 

import whisper
model = whisper.load_model('base.en')

# %%
import os
import pandas as pd

dir_path = '/content/'
dir_files = os.listdir(dir_path)
str1 = 'wav'
flist = []

for i in range(0, len(dir_files)):
  str2 = dir_files[i]
  if str1 in str2:
    flist.append(str2)
flist

df = pd.DataFrame()
n = len(flist)
nt = n + 1
fn = range(1, nt)
df['ID'] = fn
df['Filename'] = flist

df
# Out:
#    ID  Filename
# 0   1  SE01.wav
# 1   2  SE02.wav
# 2   3  SE03.wav
# time: 14.1 ms (started: 2023-01-05 15:25:56 +00:00)

# %%
#@markdown Runtime set up
# %%capture
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# time: 522 µs (started: 2023-01-05 15:12:41 +00:00)

# %%
rname = input("Type ID")
ind = int(rname) - 1
myf = df['Filename'][ind]
result = model.transcribe(myf, language="en",fp16=False)
print('Filename: %s'%myf)
print('='*30)

print("Speech-to-text (recognized): %s"%result["text"])
# Out:
# Type ID1
# Filename: SE01.wav
# ==============================
# Speech-to-text (recognized):  When the sunlight strikes raindrops in the air, they act as a prism and form a rainbow.
# time: 2.83 s (started: 2023-01-05 15:27:43 +00:00)

# %% [markdown]
# Continue to check from here (0106)

# %%
## R1 (Run this only once! Remove the hashtag to run)
runtimedata = []
# Out:
# time: 379 µs (started: 2023-01-05 15:29:34 +00:00)

# %%
#@markdown # R2
import time
import pandas as pd

def measure_time(function):
  start = time.time()
  function()
  end = time.time()
  return end - start

rname = input("Type ID: ")
ind = int(rname) - 1
myf = df['Filename'][ind]

def code_to_measure():
# your code here  
  result = model.transcribe(myf, language="en",fp16=False)

runtime = measure_time(code_to_measure)
print(f"Runtime: {runtime} seconds")

print('Filename: %s'%myf)
print('='*30)
print("Speech-to-text (recognized): %s"%result["text"])  

# df1 = pd.DataFrame({"function": ["code_to_measure"], "runtime": [runtime]})
print("="*30)
data = {myf: round(runtime,3)}
runtimedata.append(data)
print(runtimedata)
# Out:
# Type ID: 3
# Runtime: 0.36184263229370117 seconds
# Filename: SE03.wav
# ==============================
# Speech-to-text (recognized):  When the sunlight strikes raindrops in the air, they act as a prism and form a rainbow.
# ==============================
# [{'SE03.wav': 0.362}]
# time: 2.7 s (started: 2023-01-05 15:29:37 +00:00)

# %%
Audio("SE02.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# time: 15.7 ms (started: 2023-01-05 15:28:52 +00:00)

# %%
rundf = pd.DataFrame()
keydata = []
valuedata = []
n = len(runtimedata) + 1

for i in range(0, n):
  current = runtimedata[i]
  for key, value in current.items():
      a1 = key
      a2 = value
      keydata.append(a1)
      valuedata.append(a2)

rundf['FILENAME'] = keydata
rundf['RUNTIME'] = valuedata

rundf
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-13c73fd9e237> in <module>
#       5
#       6 for i in range(0, n):
# ----> 7   current = runtimedata[i]
#       8   for key, value in current.items():
#       9       a1 = key
#
# IndexError: list index out of range
# time: 24.8 ms (started: 2023-01-05 15:29:04 +00:00)
